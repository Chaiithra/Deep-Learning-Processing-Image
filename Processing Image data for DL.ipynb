# %%
# !pip install requests pillow

# %%
import requests
from PIL import Image
from io import BytesIO

# %%
url = 'https://tractive.com/blog/wp-content/uploads/2016/04/puppy-care-guide-for-new-parents.jpg'

# %%
# Sending a GET request to the url

response = requests.get(url)

# %%
# Checking if the request was successful

if response.status_code ==200:
    
    # Open the image and save it
    image = Image.open(BytesIO(response.content))
    image.save('dog.jpg')
    print('Downloaded: Successful')
else:
    print(f'Download: Failed. Status code: {response.status_code}')
# Out:
# Downloaded: Successful

# %% [markdown]
# Libraries that can be used for Image Processing

# %% [markdown]
# 1. matplotlib.image
# 2. Pillow
# 3. OpenCV ( cv2 )

# %%
# Importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# Loading the Image through matplotlib.image module

img = mpimg.imread(r"C:\Users\HP\OneDrive\Desktop\15 Day Resume Challenge\dog.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1365, 2048, 3)

# %%
print(img)
# Out:
# [[[148 181   4]
#   [148 181   4]
#   [149 182   5]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[147 180   5]
#   [148 181   4]
#   [148 181   4]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  [[145 179   4]
#   [145 179   4]
#   [146 180   5]
#   ...
#   [128 148   0]
#   [128 148   0]
#   [128 148   0]]
#
#  ...
#
#  [[ 76  69  23]
#   [ 76  69  23]
#   [ 75  68  22]
#   ...
#   [135 106  38]
#   [136 106  36]
#   [136 106  36]]
#
#  [[ 76  69  23]
#   [ 76  69  23]
#   [ 75  68  22]
#   ...
#   [135 106  38]
#   [136 106  36]
#   [136 106  36]]
#
#  [[ 76  69  23]
#   [ 76  69  23]
#   [ 75  68  22]
#   ...
#   [135 106  38]
#   [136 106  36]
#   [136 106  36]]]

# %%
# Displaying the image fro mnumpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image usin Pillow library

# %%
from PIL import Image

# %%
img = Image.open(r"C:\Users\HP\OneDrive\Desktop\15 Day Resume Challenge\dog.jpg")
img_resized = img.resize((200,200))
print(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x187CAC51FF0>

# %%
img_resized.save('img_resized.jpg')

# %%
# Displaying the image from numpy array

img_resized = mpimg.imread(r"C:\Users\HP\OneDrive\Desktop\15 Day Resume Challenge\img_resized.jpg")
img_resized_plot = plt.imshow(img_resized)
plt.show()

# %%
print(img.size) 
print(img_resized.shape)
# Out:
# (2048, 1365)
# (200, 200, 3)

# %% [markdown]
# Converting RGB Images to Grayscale image using OpenCV

# %%
# Importing OpenCV library

import cv2

# %%
img = cv2.imread(r"C:\Users\HP\OneDrive\Desktop\15 Day Resume Challenge\dog.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1365, 2048, 3)

# %%
grayscale_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_img)
# Out:
# numpy.ndarray

# %%
grayscale_img.shape
# Out:
# (1365, 2048)

# %%
plt.imshow(grayscale_img, cmap = 'gray')
plt.axis('off')
plt.show()
